# %% [markdown]
# # Part 2: Constructing SVD Music Recommender System

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse.linalg import svds
import pandas as pd
from scipy.sparse import csr_matrix
import scipy.sparse
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ollie\\Documents'

# %%
triplets_df = pd.read_csv('triplets_df.csv')

# %%
song_df = pd.read_csv('songs_df.csv')

# %%
triplets_df['user_id'] = triplets_df['user_id'].astype('category')
triplets_df['song_id'] = triplets_df['song_id'].astype('category')

# %%
# Load in sparse matrix formed in Part 1
sparse_matrix = scipy.sparse.load_npz('sparse_matrix.npz')

# %%
# sparse_matrix needs to be of dtype float32 or 64
sparse_matrix.dtype
# Out:
# dtype('int64')

# %%
# Convert matrix to appropriate type
sparse_matrix = csr_matrix(sparse_matrix, dtype=float)

# %%
sparse_matrix = sparse_matrix.astype(np.float32)

# %%
sparse_matrix.dtype
# Out:
# dtype('float32')

# %%
# In order construct an SVD we need to decide on a k value for latent features

# %%
U, sigma, Vt = svds(sparse_matrix, k=6000)

# %%
sigma = np.diag(sigma)

# %%
# When trying to predict across all users in the matrix we run into memory allocation issues
# One way around this is to only predict for a particular user, on a user by user basis
# SVD can still train on the whole dataset and get the latent features, meaning it's still drawing on all user-song interactions for predictions

# %%
def predict_for_user(user_index, U, sigma, Vt):
    user_U = U[user_index, :]
    user_predictions = np.dot(np.dot(user_U, sigma), Vt)
    return user_predictions

# We will get prediction for the first user - user 0
user_predictions = predict_for_user(0, U, sigma, Vt)

# %%
user_predictions
# Out:
# array([ 0.00191561,  0.01210143,  0.00053172, ..., -0.00950143,
#         0.00726082, -0.00486799], dtype=float32)

# %%
# Write function to generate recommendations from this users predictions

# %%
def generate_recommendations(user_index, user_predictions, interaction_matrix, song_id_map, n=10):
   
    # Get items the user has already interacted with
    user_interacted_items = interaction_matrix[user_index].nonzero()[1]
    
    # Exclude already interacted items by setting their prediction scores to -np.inf
    user_predictions[user_interacted_items] = -np.inf
    
    # Get the indices of the top N recommendations, -n gives the last n but argsort is in reverse so use [::-1]
    top_n_indices = np.argsort(user_predictions)[-n:][::-1]
    
    # Map the indices back to item (song) IDs
    top_n_item_ids = [song_id_map[idx] for idx in top_n_indices]
    
    return top_n_item_ids

# %%
# For this function to work  we will need to pass in a mapping
# This is because the recommendation gives us top_n_indices, the indicies found in the sparce matrix
# These need to be mapped back to actual song_ids, then from song ids to titles

# %%
# -- Mapping Explanation --
# This creates a dictionary where the key is idx and song_id is original song_id from triplets_df
# This works because when the csr was programmed orginally, we did triplets_df['song_id'].cat.codes
# This assigns a unique code from 0 to each song_id. 
# Doing .cat.categories returns all these song_id in the order of their assigned codes, so enumerate is used to form this mapping
song_id_map = {idx: song_id for idx, song_id in enumerate(triplets_df['song_id'].cat.categories)}

# %%
# View dictionary mapping
song_id_map
# Out:
# {0: 'SOAAAGQ12A8C1420C8',
#  1: 'SOAACPJ12A81C21360',
#  2: 'SOAACSG12AB018DC80',
#  3: 'SOAAEJI12AB0188AB5',
#  4: 'SOAAFAC12A67ADF7EB',
#  5: 'SOAAFYH12A8C13717A',
#  6: 'SOAAJMQ12A6D4F7D17',
#  7: 'SOAAKPM12A58A77210',
#  8: 'SOAALWN12A6D4F7FDA',
#  9: 'SOAAMOW12AB018149B',
#  10: 'SOAAOYI12AB01831CE',
#  11: 'SOAAROC12A6D4FA420',
#  12: 'SOAARXR12A8C133D15',
#  13: 'SOAATHE12A8C13ADD6',
#  14: 'SOAATLI12A8C13E319',
#  15: 'SOAAUKC12AB017F868',
#  16: 'SOAAVUV12AB0186646',
#  17: 'SOAAWEE12A6D4FBEC8',
#  18: 'SOABGOB12A6701D1FA',
#  19: 'SOABHNP12A8AE46E82',
#  20: 'SOABHYV12A6D4F6D0F',
#  21: 'SOABJBU12A8C13F63F',
#  22: 'SOABJTC12A58A7DE0E',
#  23: 'SOABNLP12A6D4F87F4',
#  24: 'SOABNPW12A6D4FC9B5',
#  25: 'SOABOHM12AB018509C',
#  26: 'SOABOXV12AC3DF82F7',
#  27: 'SOABPQU12A58A78441',
#  28: 'SOABQTG12A6701F3DB',
#  29: 'SOABRAB12A6D4F7AAF',
#  30: 'SOABTTR12A6D4FC2EB',
#  31: 'SOABXNE12A8C13B818',
#  32: 'SOACBLB12AB01871C7',
#  33: 'SOACDMD12A67AD8332',
#  34: 'SOACERJ12A67AD865E',
#  35: 'SOACGVR12A8C13B60A',
#  36: 'SOACIPG12A8AE47E1C',
#  37: 'SOACKIA12A6D4F73D7',
#  38: 'SOACMJJ12A6D4FC66A',
#  39: 'SOACNQJ12A8C13B09E',
#  40: 'SOACPBY12A8C13FEF9',
#  41: 'SOACPSU12A81C231EF',
#  42: 'SOACRBY12AB017C757',
#  43: 'SOACWQZ12A67ADE5EC',
#  44: 'SOACXET12AB01852E3',
#  45: 'SOACYKU12A5891CC64',
#  46: 'SOACYUL12A6D4F9C79',
#  47: 'SOADCFY12A6310E353',
#  48: 'SOADELR12AB0181A6D',
#  49: 'SOADFMR12A6701FB5F',
#  50: 'SOADISH12AB018DFAC',
#  51: 'SOADJGO12AB0185D5B',
#  52: 'SOADJQJ12A8C141D38',
#  53: 'SOADKJJ12A67ADB371',
#  54: 'SOADKOB12AB017DB36',
#  55: 'SOADMBB12AB017C0F1',
#  56: 'SOADMKP12A8C13BAA4',
#  57: 'SOADMTV12A6701FA3F',
#  58: 'SOADOQJ12A8AE45C7E',
#  59: 'SOADOVQ12AB01797EB',
#  60: 'SOADOWZ12AB01887EF',
#  61: 'SOADQMO12A8C136FF9',
#  62: 'SOADQPP12A67020C82',
#  63: 'SOADSKA12AB01860FA',
#  64: 'SOADVUP12AB0185246',
#  65: 'SOADZWN12A8C136C60',
#  66: 'SOAECLL12A58A7E668',
#  67: 'SOAEEMQ12A8C142D36',
#  68: 'SOAEEXF12A8C13E49F',
#  69: 'SOAEGIH12A6D4F8B51',
#  70: 'SOAEHEX12A8C13EFA4',
#  71: 'SOAEIDM12A6D4F8463',
#  72: 'SOAEIFW12A8C1391E4',
#  73: 'SOAEJAC12A58A7C609',
#  74: 'SOAEJNB12A8C13F64D',
#  75: 'SOAEJVN12A8C14346F',
#  76: 'SOAEKIE12A6701FEAD',
#  77: 'SOAEPVF12A8C13722D',
#  78: 'SOAESGK12A8C138488',
#  79: 'SOAETMP12A8C140E7F',
#  80: 'SOAEUPY12A58A79B84',
#  81: 'SOAEURY12A8C13CA33',
#  82: 'SOAEUYZ12AF72A6379',
#  83: 'SOAEYBP12AB0184573',
#  84: 'SOAEYCM12A58A7CDDE',
#  85: 'SOAFAXA12A58A7BB11',
#  86: 'SOAFBKA12A58A7ACCF',
#  87: 'SOAFELG12A8C1323D5',
#  88: 'SOAFHIF12AB0184446',
#  89: 'SOAFKAJ12AB0181B91',
#  90: 'SOAFLLJ12A8C133C8D',
#  91: 'SOAFPPR12A8AE46454',
#  92: 'SOAFPSO12AF72A4521',
#  93: 'SOAFQGA12A8C1367FA',
#  94: 'SOAFQMR12A6D4F755A',
#  95: 'SOAFRIN12A81C22087',
#  96: 'SOAFTFX12A6D4F3B78',
#  97: 'SOAFTRR12AF72A8D4D',
#  98: 'SOAFVWW12A58A7E1CB',
#  99: 'SOAGFFD12AC909761F',
#  100: 'SOAGGLN12AB018AC9B',
#  101: 'SOAGHVC12A8C13B62E',
#  102: 'SOAGIAY12AB0183D8F',
#  103: 'SOAGKBO12AB0186943',
#  104: 'SOAGLRX12A6D4F822B',
#  105: 'SOAGMLZ12A8C13B808',
#  106: 'SOAGNRU12A58A7AC5C',
#  107: 'SOAGRCT12AB017B552',
#  108: 'SOAGSYE12A58A7A5A7',
#  109: 'SOAGWPY12AB018CD74',
#  110: 'SOAHEEC12A6BD4DAA4',
#  111: 'SOAHIJF12A6D4FDB77',
#  112: 'SOAHJQY12AB018534B',
#  113: 'SOAHKNJ12AF72A54BE',
#  114: 'SOAHLGV12AF72A6DFC',
#  115: 'SOAHPVM12AB018868C',
#  116: 'SOAHVBG12A8C1439A1',
#  117: 'SOAHVLJ12A58A76DD6',
#  118: 'SOAIAAT12A8C145D49',
#  119: 'SOAICBB12A6D4F594D',
#  120: 'SOAIDAS12A6D4F6749',
#  121: 'SOAIIAR12A6D4FAC81',
#  122: 'SOAIILB12A58A776F7',
#  123: 'SOAILNW12A8C134FB7',
#  124: 'SOAIMFG12AB0189AC2',
#  125: 'SOAIOFW12A8C13FAC0',
#  126: 'SOAIQCY12A8AE4616E',
#  127: 'SOAIQYM12A6701F507',
#  128: 'SOAIRYO12AB018C2DA',
#  129: 'SOAIUPE12AB0185750',
#  130: 'SOAIVCH12AC468AAB1',
#  131: 'SOAIVZL12A8C139DFB',
#  132: 'SOAIWAB12A8C13710A',
#  133: 'SOAIWCC12AC907107C',
#  134: 'SOAJAFJ12A58A7B75A',
#  135: 'SOAJDBZ12A6D4FA3C8',
#  136: 'SOAJFTU12A6701E0A3',
#  137: 'SOAJHHJ12A6BD4E204',
#  138: 'SOAJHLR12A8C13CC11',
#  139: 'SOAJJDS12A8C13A3FB',
#  140: 'SOAJNYK12AF729F33B',
#  141: 'SOAJQCL12A58A79581',
#  142: 'SOAJTNF12A6BD5315D',
#  143: 'SOAJVOL12AAF3B25E6',
#  144: 'SOAJWRM12A8C13CF2B',
#  145: 'SOAJXWO12A8C1436D0',
#  146: 'SOAJYLI12AB01831B8',
#  147: 'SOAJYSF12A6701D300',
#  148: 'SOAKCFL12A6D4F9CC5',
#  149: 'SOAKDHD12A6310F1AE',
#  150: 'SOAKDLX12A67ADAFC5',
#  151: 'SOAKHOF12A8C13C72A',
#  152: 'SOAKILN12A8C1432C2',
#  153: 'SOAKIMP12A8C130995',
#  154: 'SOAKMDU12A8C1346A9',
#  155: 'SOAKMFY12A58A7DC21',
#  156: 'SOAKOEA12AB018848B',
#  157: 'SOAKPMX12AB018193B',
#  158: 'SOAKPQJ12A8C13D812',
#  159: 'SOAKTQP12A58A77455',
#  160: 'SOAKWFZ12A8C1389E7',
#  161: 'SOAKWHP12AB018A3F8',
#  162: 'SOAKYBR12AB0185EE8',
#  163: 'SOAKYBX12AB018281B',
#  164: 'SOAKZQA12A6D4F80C1',
#  165: 'SOALBSB12A58A814C0',
#  166: 'SOALDLA12A6D4F8657',
#  167: 'SOALEQA12A58A77839',
#  168: 'SOALERS12A6701E91F',
#  169: 'SOALFJM12A6701C40F',
#  170: 'SOALHDV12A6D4F98DD',
#  171: 'SOALHPM12AB0182241',
#  172: 'SOALISX12AB017FDE8',
#  173: 'SOALITF12A6310DFCD',
#  174: 'SOALJAA12A6702085C',
#  175: 'SOALJBV12AB017FC3A',
#  176: 'SOALJTF12A6310E8DA',
#  177: 'SOALKBV12A6D4F6EE2',
#  178: 'SOALLQK12AF72A275F',
#  179: 'SOALMAS12AC468E8A9',
#  180: 'SOALPEC12AB0185D8F',
#  181: 'SOALPQQ12A6701F302',
#  182: 'SOALRMF12A8C1436A7',
#  183: 'SOALTWW12A8C132292',
#  184: 'SOALUPO12A8C131951',
#  185: 'SOALVDS12A8C13A389',
#  186: 'SOALVJT12A8C14307D',
#  187: 'SOALVOP12A6D4F5DA1',
#  188: 'SOAMAJG12A8C134DEE',
#  189: 'SOAMDXO12A8C131E2F',
#  190: 'SOAMEVJ12A6701E393',
#  191: 'SOAMFCO12A6701F117',
#  192: 'SOAMFRD12AF72A84BD',
#  193: 'SOAMHNB12A6D4F8E9F',
#  194: 'SOAMIQK12A6701D94F',
#  195: 'SOAMKOV12A81C21C44',
#  196: 'SOAMKRU12A58A814CB',
#  197: 'SOAMNGZ12A6D4F8702',
#  198: 'SOAMPRJ12A8AE45F38',
#  199: 'SOAMQFH12AB017DB51',
#  200: 'SOAMSPW12AB017F147',
#  201: 'SOAMWDX12A58A7B898',
#  202: 'SOAMZFX12A8C131F7C',
#  203: 'SOANEFZ12A6D4F86D8',
#  204: 'SOANKGB12AB017F97D',
#  205: 'SOANKKC12A6310F346',
#  206: 'SOANMWU12A6D4F9246',
#  207: 'SOANOQW12A58A793D2',
#  208: 'SOANQFY12AB0183239',
#  209: 'SOANRRH12AB01861EB',
#  210: 'SOANSPC12A6702154A',
#  211: 'SOANUKH12AB0182B83',
#  212: 'SOAOAFS12AAF3B5120',
#  213: 'SOAOAHZ12A8C13AAF1',
#  214: 'SOAOAWR12A58A7B7BE',
#  215: 'SOAOBEK12AF72A9021',
#  216: 'SOAOBWU12A8C146B06',
#  217: 'SOAOBZA12AF72A5914',
#  218: 'SOAODHY12A8C13C8B5',
#  219: 'SOAOERV12AF72A48FC',
#  220: 'SOAOFBI12A8C143E28',
#  221: 'SOAOGOV12A8C13ACED',
#  222: 'SOAOHEN12A6D4FCCF0',
#  223: 'SOAOHXZ12A6D4FBC78',
#  224: 'SOAOJYY12A58A7B2F9',
#  225: 'SOAONVU12A6D4F4759',
#  226: 'SOAOOJK12A8C144AA2',
#  227: 'SOAOOOS12AB017F329',
#  228: 'SOAOOWF12A8C1347EC',
#  229: 'SOAOPCG12AC468D27E',
#  230: 'SOAOPNQ12A81C21E35',
#  231: 'SOAOQAM12A67ADE250',
#  232: 'SOAOQFD12A6D4FAAA9',
#  233: 'SOAOQSY12A8C139550',
#  234: 'SOAOSDF12A58A779F1',
#  235: 'SOAOSNO12A6D4FA76F',
#  236: 'SOAOULW12AAF3B5B85',
#  237: 'SOAOUWL12A8C146558',
#  238: 'SOAOVUU12AB0186929',
#  239: 'SOAOVXC12AB0184BDE',
#  240: 'SOAOZFA12A58A805AE',
#  241: 'SOAPBKQ12A8C13ABC0',
#  242: 'SOAPBSH12A58A80492',
#  243: 'SOAPBTS12AF729BFB8',
#  244: 'SOAPDFU12A8C13778B',
#  245: 'SOAPFCA12A8C1349FB',
#  246: 'SOAPFVS12A6701F8B0',
#  247: 'SOAPHBN12AF72A60EF',
#  248: 'SOAPIHX12AB0184CB1',
#  249: 'SOAPLOI12AB018CCF4',
#  250: 'SOAPLPB12A8C1456F7',
#  251: 'SOAPLWH12A8C140D4F',
#  252: 'SOAPNSG12A8C13481A',
#  253: 'SOAPSFK12AC46890F8',
#  254: 'SOAPSLE12A8C131934',
#  255: 'SOAPUDJ12A67ADE98D',
#  256: 'SOAPXMM12A8C13B5BA',
#  257: 'SOAQAIZ12A6310F100',
#  258: 'SOAQGES12A8C133FB5',
#  259: 'SOAQJRX12A6701F999',
#  260: 'SOAQKDM12A67020E0D',
#  261: 'SOAQKGW12AB018BE11',
#  262: 'SOAQLWB12A8C13BA9D',
#  263: 'SOAQMEC12A67ADD881',
#  264: 'SOAQMNM12AB0188D7A',
#  265: 'SOAQNRN12AF72A7E50',
#  266: 'SOAQSZE12A8C145278',
#  267: 'SOAQTNT12A6701F957',
#  268: 'SOAQTQO12A6D4FCD0A',
#  269: 'SOAQUBQ12A67ADE359',
#  270: 'SOARBUV12A6310F1B2',
#  271: 'SOAREWP12A8C132F0F',
#  272: 'SOARFGZ12AB017AFCD',
#  273: 'SOARTDL12A67ADAD83',
#  274: 'SOARTRF12AB0181F4D',
#  275: 'SOARUBA12A8C138E3D',
#  276: 'SOARUPP12AB01842E0',
#  277: 'SOARXRU12A8C134ABB',
#  278: 'SOARYZA12A6D4FAB9B',
#  279: 'SOASBIM12A58A7B2DB',
#  280: 'SOASEAH12A67AD80DD',
#  281: 'SOASEMJ12A8C13C490',
#  282: 'SOASMDJ12A6D4F6CDF',
#  283: 'SOASMDL12A6D4FD8C5',
#  284: 'SOASNQV12A8AE48819',
#  285: 'SOASOOD12A8C13EE86',
#  286: 'SOASPCN12A6D4F8589',
#  287: 'SOASRCN12AB0187549',
#  288: 'SOASTPI12A58A7E0F8',
#  289: 'SOASTSF12A8C1420B5',
#  290: 'SOASVLD12AB0186887',
#  291: 'SOASWDH12A8C1325EE',
#  292: 'SOASXQD12AB018902F',
#  293: 'SOASZHJ12B0B80A18B',
#  294: 'SOATBPC12B34F265AF',
#  295: 'SOATHTW12A58A7EDB5',
#  296: 'SOATJMN12AB0184D1E',
#  297: 'SOATKQE12A8C133A97',
#  298: 'SOATLAK12A8C13F422',
#  299: 'SOATNYF12AF72A8D48',
#  300: 'SOATPFD12A8C136B88',
#  301: 'SOATQYE12A6D4F8167',
#  302: 'SOATRMX12AB0180E3B',
#  303: 'SOATSLL12AB017B862',
#  304: 'SOATVMX12AB0182308',
#  305: 'SOAUBGU12A6701C57A',
#  306: 'SOAUCNT12A8C140C2D',
#  307: 'SOAUDET12A6D4F96B7',
#  308: 'SOAUEJL12AB01867F6',
#  309: 'SOAUFID12A8C13AF6C',
#  310: 'SOAUFOF12AB0180C65',
#  311: 'SOAUIZJ12A6D4FC011',
#  312: 'SOAUJCB12AB0181B7D',
#  313: 'SOAULLM12A8C134289',
#  314: 'SOAUNAX12AB01876D0',
#  315: 'SOAUPFC12AB0184CE4',
#  316: 'SOAUWWV12AF729E642',
#  317: 'SOAUWYT12A81C206F1',
#  318: 'SOAUXEN12A81C23960',
#  319: 'SOAUZAA12A6701F9B6',
#  320: 'SOAVAVB12AB0180687',
#  321: 'SOAVBKQ12AB01834D4',
#  322: 'SOAVCHX12A6D4FA7B6',
#  323: 'SOAVCTS12A8C13EDF2',
#  324: 'SOAVFLR12A8C138576',
#  325: 'SOAVGOD12A6D4F7783',
#  326: 'SOAVIJW12AB018269B',
#  327: 'SOAVJBU12AAF3B370C',
#  328: 'SOAVLJR12AC46883DC',
#  329: 'SOAVMUZ12A67ADE3EF',
#  330: 'SOAVPPJ12A8C13EFBC',
#  331: 'SOAVQRL12A6D4F86E4',
#  332: 'SOAVQRP12A8C13120B',
#  333: 'SOAVTFX12AB0188D87',
#  334: 'SOAVWHY12AB017C6C0',
#  335: 'SOAVYHI12A6D4F766A',
#  336: 'SOAWFKO129F06933A7',
#  337: 'SOAWIDW12A81C22AEB',
#  338: 'SOAWJSH12A8C13AE09',
#  339: 'SOAWKRV12A6D4F7EF7',
#  340: 'SOAWMKQ12A8C13C340',
#  341: 'SOAWRMA12A679AE595',
#  342: 'SOAWSML12A6310F1B7',
#  343: 'SOAWUAX12AAF3B1E58',
#  344: 'SOAWWJW12AB01814F5',
#  345: 'SOAWWSY12AB018B768',
#  346: 'SOAWXHP12AB01840AC',
#  347: 'SOAWXPY12A8C137E88',
#  348: 'SOAXAPU12A67020EF9',
#  349: 'SOAXEPS12AF729E550',
#  350: 'SOAXEYH12AF72A2E76',
#  351: 'SOAXGBS12A6310E17A',
#  352: 'SOAXGDH12A8C13F8A1',
#  353: 'SOAXHLH12A58A7C27E',
#  354: 'SOAXHYC12A8C13D3B5',
#  355: 'SOAXJHW12A81C21E1F',
#  356: 'SOAXJIC12A6D4FBFD7',
#  357: 'SOAXJOU12A6D4F6685',
#  358: 'SOAXKNC12AF72A4BF8',
#  359: 'SOAXLDX12AC468DE36',
#  360: 'SOAXMEE12A6701E730',
#  361: 'SOAXTWB12AF72A1545',
#  362: 'SOAYATB12A6701FD50',
#  363: 'SOAYDEP12A8AE45E1E',
#  364: 'SOAYETG12A67ADA751',
#  365: 'SOAYONZ12AF72A5DE3',
#  366: 'SOAYQPQ12A58A770C4',
#  367: 'SOAYQVC12A6D4F7829',
#  368: 'SOAYQXX12A58A7C47F',
#  369: 'SOAYSJV12A58A7D20C',
#  370: 'SOAYSMC12A67020927',
#  371: 'SOAYSTU12A67ADAF03',
#  372: 'SOAYTRA12A8C136D0E',
#  373: 'SOAYUTK12AB0187D96',
#  374: 'SOAYVPL12A8C134CAE',
#  375: 'SOAYVYB12A58A7917A',
#  376: 'SOAZATE12AB0185142',
#  377: 'SOAZDYK12AB01816E5',
#  378: 'SOAZFQH12A8C13D101',
#  379: 'SOAZGBW12A6702090C',
#  380: 'SOAZHNJ12A6D4F9930',
#  381: 'SOAZIYU12A8C139B48',
#  382: 'SOAZMXH12AB0186DDE',
#  383: 'SOAZPOI12A8C133A08',
#  384: 'SOAZPPR12A6D4F89C6',
#  385: 'SOAZRJG12A6D4F8A30',
#  386: 'SOAZVLB12A6D4FCC2D',
#  387: 'SOAZXMO12A8C139F2D',
#  388: 'SOAZXRD12A6D4F75A3',
#  389: 'SOAZZRB12AF729DE68',
#  390: 'SOAZZRU12AB0182B0E',
#  391: 'SOBAAAB12A6D4F95A5',
#  392: 'SOBAARL12AF72A4201',
#  393: 'SOBABRB12A6701DF4B',
#  394: 'SOBABSR12A58A7AD93',
#  395: 'SOBACCC12A6701ED85',
#  396: 'SOBADEB12AB018275F',
#  397: 'SOBADLL12A6D4F8FEA',
#  398: 'SOBAKDJ12A8C13E557',
#  399: 'SOBAKOT12A67021B3D',
#  400: 'SOBANHD12A58A7BB7C',
#  401: 'SOBAPJF12A670208FD',
#  402: 'SOBAQTV12A8C142277',
#  403: 'SOBATYS12A58A76C6E',
#  404: 'SOBAUXH12A67ADD86C',
#  405: 'SOBAXIM12A6D4F8C47',
#  406: 'SOBBAFQ12A8C141BF2',
#  407: 'SOBBCWG12AF72AB9CB',
#  408: 'SOBBGTM12A6D4F6199',
#  409: 'SOBBHQG12A58A7ADC6',
#  410: 'SOBBHVN12A6702162D',
#  411: 'SOBBJKR12A6D4FA788',
#  412: 'SOBBKGF12A8C1311EE',
#  413: 'SOBBMDR12A8C13253B',
#  414: 'SOBBMXL12A6D4F767B',
#  415: 'SOBBNDM12A58A78370',
#  416: 'SOBBNZX12A8C139601',
#  417: 'SOBBONW12AB0180FE6',
#  418: 'SOBBQCZ12AB018455A',
#  419: 'SOBBRFA12A6701FBC4',
#  420: 'SOBBVDC12AB01806C6',
#  421: 'SOBBXNX12AF72A4883',
#  422: 'SOBBZPM12AB017DF4B',
#  423: 'SOBCGRY12A6701DE8E',
#  424: 'SOBCKIM12A8C13936C',
#  425: 'SOBCLWO12A6D4F83AD',
#  426: 'SOBCMUG12AB017D50A',
#  427: 'SOBCNJU12A8C13F270',
#  428: 'SOBCOWD12A6701FD78',
#  429: 'SOBCOYF12A58A7B527',
#  430: 'SOBCPBL12A8C139768',
#  431: 'SOBCRSV12A6D4F3C93',
#  432: 'SOBCRUE12A81C224B5',
#  433: 'SOBCSFE12A6D4F814A',
#  434: 'SOBCVZT12AF72A4506',
#  435: 'SOBCXCW12A8C13BFDD',
#  436: 'SOBCZZG12AB01882C1',
#  437: 'SOBDASI12A8C13E814',
#  438: 'SOBDCSW12A58A78FB9',
#  439: 'SOBDGJS12A8C1411FD',
#  440: 'SOBDGQD12A58A7C5DF',
#  441: 'SOBDJMW12A8C137318',
#  442: 'SOBDJYZ12A8C132ADA',
#  443: 'SOBDKVR12A8C13E705',
#  444: 'SOBDMNP12AF72AB1E1',
#  445: 'SOBDQMB12AB0189045',
#  446: 'SOBDRND12A8C13FD08',
#  447: 'SOBDVAK12AC90759A2',
#  448: 'SOBDWET12A6701F114',
#  449: 'SOBDYYK12A81C23221',
#  450: 'SOBDZKO12A67020664',
#  451: 'SOBDZNY12A6310E1CA',
#  452: 'SOBEAHS12A6D4F97A6',
#  453: 'SOBEBRO12A8C13A69E',
#  454: 'SOBEHXG12A8C138D22',
#  455: 'SOBEITD12A6D4F8C38',
#  456: 'SOBEJBH12AC468A455',
#  457: 'SOBEMUE12A6701E076',
#  458: 'SOBEOYA12AB0186F10',
#  459: 'SOBEQEO12A6D4F6589',
#  460: 'SOBETFO12AB018668B',
#  461: 'SOBEUDN12A81C2143D',
#  462: 'SOBEVGM12A67ADBCA7',
#  463: 'SOBEZLE12A6D4F7D0A',
#  464: 'SOBFFEN12A6701C878',
#  465: 'SOBFGZA12A8AE4542A',
#  466: 'SOBFLMV12A6701E740',
#  467: 'SOBFMHC12A6D4F9401',
#  468: 'SOBFMQE12AB0184181',
#  469: 'SOBFNRW12A6D4F7BCA',
#  470: 'SOBFONC12A8C140932',
#  471: 'SOBFPJC12A58A7D1AB',
#  472: 'SOBFPNI12A81C2243B',
#  473: 'SOBFRNE12A6D4F7995',
#  474: 'SOBFSKY12AB0182C6F',
#  475: 'SOBFSQU12A8151AB7B',
#  476: 'SOBFUWO12A8C13F316',
#  477: 'SOBGBUO12AF72A3513',
#  478: 'SOBGCCI12A6D4F8411',
#  479: 'SOBGDGX12A6D4F531E',
#  480: 'SOBGDOL12A6D4F6F21',
#  481: 'SOBGDPS12A8C13C214',
#  482: 'SOBGJBA12A6D227291',
#  483: 'SOBGLBX12A8C13AE8E',
#  484: 'SOBGMYK12A6D4F6730',
#  485: 'SOBGNMG12A8C133DFD',
#  486: 'SOBGPEH12A6D4F818B',
#  487: 'SOBGPHU12A8C1424E3',
#  488: 'SOBGQHH12A8151CAC5',
#  489: 'SOBGVLX12A6310DF8F',
#  490: 'SOBGVPD12A81C217B0',
#  491: 'SOBGYNC12A6D4FBFAD',
#  492: 'SOBHBKJ12A6D4F9D00',
#  493: 'SOBHDZO12A6D4FD169',
#  494: 'SOBHHHO12A58A78B94',
#  495: 'SOBHIJM12AB018194F',
#  496: 'SOBHIJO12A6D4FA26C',
#  497: 'SOBHJYY12AF72A8A23',
#  498: 'SOBHNKR12AB0186218',
#  499: 'SOBHNWV12AB0184DEE',
#  500: 'SOBHPQB12A8C13C6A8',
#  501: 'SOBHWHZ12AF72A409D',
#  502: 'SOBHXTN12A67021129',
#  503: 'SOBHXWK12A6D4FD10E',
#  504: 'SOBIATB12A8C1349F9',
#  505: 'SOBIFBZ12AF72A2DAF',
#  506: 'SOBIIAC12A8C13F348',
#  507: 'SOBIKOJ12A8C14134B',
#  508: 'SOBIKPR12A6D4FAF1E',
#  509: 'SOBIKPX12A58A78775',
#  510: 'SOBILME12A6701EEAB',
#  511: 'SOBILMS12AB018D900',
#  512: 'SOBIMTY12A6D4F931F',
#  513: 'SOBIONB12AB0185862',
#  514: 'SOBIPDF12A8C1360A2',
#  515: 'SOBIQVE12A8C13FEFF',
#  516: 'SOBIQWH12A8C13BCDE',
#  517: 'SOBITLI12A8AE47E63',
#  518: 'SOBITYB12AB01830F5',
#  519: 'SOBIWNU12A6BD56C1E',
#  520: 'SOBIXFH12A6D4F7823',
#  521: 'SOBJBEU12AF729D526',
#  522: 'SOBJBIZ12A8C132861',
#  523: 'SOBJCFV12A8AE469EE',
#  524: 'SOBJDDA12A6BD53159',
#  525: 'SOBJDRT12A670205F8',
#  526: 'SOBJDVT12A6701E079',
#  527: 'SOBJHIC12A6D4F4A2D',
#  528: 'SOBJIZY12A6701F11A',
#  529: 'SOBJKAC12AB017E1DC',
#  530: 'SOBJMPB12A6701F785',
#  531: 'SOBJMRV12A6D4FAB28',
#  532: 'SOBJOSC12A8C137A74',
#  533: 'SOBJRIA12A8C14254C',
#  534: 'SOBJSLW12A6D4F9158',
#  535: 'SOBJSXD12A6D4F966E',
#  536: 'SOBJUIV12AF72A7997',
#  537: 'SOBJUKG12A58A7DCA8',
#  538: 'SOBJXHH12A58A7AEB9',
#  539: 'SOBJXPJ12AB0186089',
#  540: 'SOBJYFB12AB018372D',
#  541: 'SOBKCBP12A8AE48322',
#  542: 'SOBKEVK12AB0183FE8',
#  543: 'SOBKIMB12A8C136DE9',
#  544: 'SOBKKUJ12A6D4FC8AB',
#  545: 'SOBKLTU12A58A7FB77',
#  546: 'SOBKMNJ12AF729BCA3',
#  547: 'SOBKPTT12A8AE45F67',
#  548: 'SOBKQUT12A6D4F7013',
#  549: 'SOBKRVG12A8C133269',
#  550: 'SOBKTKO12AB01857FD',
#  551: 'SOBKXDF12A67ADF7EC',
#  552: 'SOBKYRR12A67020866',
#  553: 'SOBLANY12A8C14382E',
#  554: 'SOBLBER12A6D4FCAEE',
#  555: 'SOBLEMV127D978257F',
#  556: 'SOBLIPF12AF729F53E',
#  557: 'SOBLLNN12AF72A5D51',
#  558: 'SOBLLXY12A8C140136',
#  559: 'SOBLPAU12A8C140704',
#  560: 'SOBLQIH12A6D4F986F',
#  561: 'SOBLRAF12A8C13D091',
#  562: 'SOBLSTM12A8C140FC9',
#  563: 'SOBLTMH12A6D4FA44D',
#  564: 'SOBLWSM12A8C131CDD',
#  565: 'SOBLXNR12A8AE47722',
#  566: 'SOBLYCD12A6701F343',
#  567: 'SOBLYYV12AB0186439',
#  568: 'SOBLZJI12A6D4F7819',
#  569: 'SOBMARH12A8C1437CA',
#  570: 'SOBMCEI12A6D4F65BD',
#  571: 'SOBMGEE12A8C137B1D',
#  572: 'SOBMIPX12A6701C7A7',
#  573: 'SOBMKJU12A6D4F7128',
#  574: 'SOBMLKS12A6310FF60',
#  575: 'SOBMNXE12A8C140F8A',
#  576: 'SOBMQUW12AB0184E28',
#  577: 'SOBMRKB12A8AE481D0',
#  578: 'SOBMSCQ12AAF3B51B7',
#  579: 'SOBMTQD12AB01833D0',
#  580: 'SOBMVXX12A8C13D19E',
#  581: 'SOBMYTR12A8C13B2D3',
#  582: 'SOBNAMV12A8C139423',
#  583: 'SOBNBWX12A8C13E6BA',
#  584: 'SOBNCNF12A8C13F62E',
#  585: 'SOBNCYQ12AB01876B5',
#  586: 'SOBNDDJ12A67AE228C',
#  587: 'SOBNDVE12A6D4FA42A',
#  588: 'SOBNGMO12A8C131CDF',
#  589: 'SOBNJIY12A8C141E74',
#  590: 'SOBNJSO12A8C13F327',
#  591: 'SOBNJZN12A67ADE984',
#  592: 'SOBNLQK12A8C131F2E',
#  593: 'SOBNNDP12A58A78284',
#  594: 'SOBNOSD12A8C13C4E0',
#  595: 'SOBNPFN12A8C142E6F',
#  596: 'SOBNPLZ12A81C2394C',
#  597: 'SOBNPQE12A6D4F7B36',
#  598: 'SOBNSME12A6701E2FD',
#  599: 'SOBNTFK12A6701F1CF',
#  600: 'SOBNTMC12A6D4FA422',
#  601: 'SOBNUYL12AB0182BCE',
#  602: 'SOBNVRV12A6D4F7F68',
#  603: 'SOBNVYD12AB018D1E9',
#  604: 'SOBNXJY12A8C13E070',
#  605: 'SOBOAFP12A8C131F36',
#  606: 'SOBOASZ12AB018104B',
#  607: 'SOBOGML12AB017FEEC',
#  608: 'SOBOGSC12A8C1440FC',
#  609: 'SOBOHSG12AB0183748',
#  610: 'SOBOIDQ12AB0184F7B',
#  611: 'SOBOJJB12A58A7D1AD',
#  612: 'SOBOLEI12A58A7E386',
#  613: 'SOBOMOX12AB017F9CF',
#  614: 'SOBONKR12A58A7A7E0',
#  615: 'SOBOOXZ12A8C13AF83',
#  616: 'SOBOSGD12A6D4F75C0',
#  617: 'SOBOUPA12A6D4F81F1',
#  618: 'SOBPAWP12A8C144CD7',
#  619: 'SOBPDZF12A8AE46DC7',
#  620: 'SOBPFAB12A8C140A2C',
#  621: 'SOBPFFZ12A58A789E9',
#  622: 'SOBPGWB12A6D4F7EF3',
#  623: 'SOBPHVB12A6D4F74DB',
#  624: 'SOBPHXV12A6D4F9FD0',
#  625: 'SOBPICV12A8151CDF1',
#  626: 'SOBPIWU12A8C140225',
#  627: 'SOBPIZR12AF72AC99D',
#  628: 'SOBPJOE12A8AE470A6',
#  629: 'SOBPJQW12A8C13B943',
#  630: 'SOBPKPW12A6701E8F9',
#  631: 'SOBPKSP12A6D4FBA0E',
#  632: 'SOBPLGR12A6D4F82BE',
#  633: 'SOBPOHI128F57D02BF',
#  634: 'SOBPQCK12AF72A2FD5',
#  635: 'SOBPQSZ12A6D4FACBB',
#  636: 'SOBPRGU12AB018DAB1',
#  637: 'SOBPRZE12A8C1313CC',
#  638: 'SOBPUVE12B0B808A06',
#  639: 'SOBPWRJ12A8C132C2D',
#  640: 'SOBPZTW12A58A773B3',
#  641: 'SOBQFSF12AAF3B451F',
#  642: 'SOBQJTZ12A58A7E619',
#  643: 'SOBQLCM12A6D4FAFCD',
#  644: 'SOBQODG12A8C13ECFF',
#  645: 'SOBQTGA12A6D4F959A',
#  646: 'SOBQTPC12AF72A24BC',
#  647: 'SOBQUNN12A6701DD71',
#  648: 'SOBQWQI12A8AE45E55',
#  649: 'SOBQXRB12AB01834D2',
#  650: 'SOBQYCF12AC909726F',
#  651: 'SOBQYWO12AB0181386',
#  652: 'SOBQZKF12A6701F50E',
#  653: 'SOBQZKH12A8AE48A02',
#  654: 'SOBRDAV12A6D4F7809',
#  655: 'SOBRFPG12A8AE4837D',
#  656: 'SOBRGZW12A8C13C541',
#  657: 'SOBRHVR12A8C133F35',
#  658: 'SOBRJNF12A8C13B63D',
#  659: 'SOBRMVI12A58A78642',
#  660: 'SOBRQUF12AF72A7728',
#  661: 'SOBRWBG12A6D4FBA2D',
#  662: 'SOBRXTB12AF729DCCC',
#  663: 'SOBRYBV12A58A7D451',
#  664: 'SOBRZCG12A6702187D',
#  665: 'SOBSAAN12A8C135B63',
#  666: 'SOBSEII12A6D4FBB1D',
#  667: 'SOBSGPF12AB018A2EC',
#  668: 'SOBSGZI12A8C13F8DF',
#  669: 'SOBSHGA12AF72AA250',
#  670: 'SOBSICO12A67020895',
#  671: 'SOBSIDS12A67ADA695',
#  672: 'SOBSIFR12A6D4F8560',
#  673: 'SOBSKOP12AF72A24AD',
#  674: 'SOBSLVH12A8C131F38',
#  675: 'SOBSNKR12A6BD4F03A',
#  676: 'SOBSOAS12A58A76FC6',
#  677: 'SOBSQDZ12AF72A50FF',
#  678: 'SOBSQYL12AB0187688',
#  679: 'SOBSRPU12A8C134E1B',
#  680: 'SOBSSGV12AB0189587',
#  681: 'SOBSTCT12A8C13DC34',
#  682: 'SOBSTEK12A8C13FFC2',
#  683: 'SOBSTHR12A67020A31',
#  684: 'SOBSYVE12A6D4F84D1',
#  685: 'SOBTCFO12A6D4FB0CA',
#  686: 'SOBTDFV12B0B80B789',
#  687: 'SOBTEDP12A6D4F970F',
#  688: 'SOBTFWO12AB01875D5',
#  689: 'SOBTGVG12AB0187543',
#  690: 'SOBTIYZ12AB0181A16',
#  691: 'SOBTKGN12AB0185912',
#  692: 'SOBTMLA12A6D4FC2EB',
#  693: 'SOBTNNG12AF72A73E8',
#  694: 'SOBTOGN12A6310F927',
#  695: 'SOBTPPJ12A8C144B53',
#  696: 'SOBTPSW12A8C142D1D',
#  697: 'SOBTRCD12A6701E976',
#  698: 'SOBTTRJ12A8C141FB4',
#  699: 'SOBTUTU12A6701F301',
#  700: 'SOBTVDE12AF72A3DE5',
#  701: 'SOBTVEI12AF72A89A2',
#  702: 'SOBTXJE12A6D4FA416',
#  703: 'SOBUBLL12A58A795A8',
#  704: 'SOBUCWN12AB018A418',
#  705: 'SOBUHQI12A6D4F7195',
#  706: 'SOBUJKP12A8C1384FB',
#  707: 'SOBUMYJ12AB01846D8',
#  708: 'SOBUOEK12A6D4F9908',
#  709: 'SOBUQUI12A58A7D307',
#  710: 'SOBUXNB12AB0182BF3',
#  711: 'SOBVDHY12A6D4F824E',
#  712: 'SOBVEQD12A8C145559',
#  713: 'SOBVFLL12AF72A4EE8',
#  714: 'SOBVHCR12AB017F44D',
#  715: 'SOBVHCU12AB0179C36',
#  716: 'SOBVHME12A6D4FACA8',
#  717: 'SOBVINO12A8AE48926',
#  718: 'SOBVJCH12A8C137023',
#  719: 'SOBVKFF12A8C137A79',
#  720: 'SOBVMDO12A6701F970',
#  721: 'SOBVMSA12A8C13C546',
#  722: 'SOBVTVL12A8C1422D7',
#  723: 'SOBVXBI12A8C13344D',
#  724: 'SOBVYMC12A6D4F9499',
#  725: 'SOBVYNO12A8C140601',
#  726: 'SOBWCVL12AB0185309',
#  727: 'SOBWDHM12A6D4F60C9',
#  728: 'SOBWFXM12AB0182808',
#  729: 'SOBWJZE12AB018165F',
#  730: 'SOBWKJK12AB017E055',
#  731: 'SOBWLMV12AF72A7B1E',
#  732: 'SOBWRTW12AB018825D',
#  733: 'SOBWSGV12AB018B5E0',
#  734: 'SOBWWIK12A6D4F9C51',
#  735: 'SOBWZRT12A81C231DA',
#  736: 'SOBXHDL12A81C204C0',
#  737: 'SOBXLTA12AB017DE82',
#  738: 'SOBXNRH12AF72A0F69',
#  739: 'SOBXNSJ12AB017B6A4',
#  740: 'SOBXOWJ12A6D4F85BA',
#  741: 'SOBXTNN12A6D4F6B48',
#  742: 'SOBXUVB12AB0188BCF',
#  743: 'SOBXVNE12A8C131DBA',
#  744: 'SOBXWKW12A8C13CD67',
#  745: 'SOBXZDZ12AB017ADCC',
#  746: 'SOBXZQP12A8C1334A7',
#  747: 'SOBYCEI12A58A7AA44',
#  748: 'SOBYDAA12A6D4F8847',
#  749: 'SOBYDXK12AB0182382',
#  750: 'SOBYHAJ12A6701BF1D',
#  751: 'SOBYJRH12A8C141C8B',
#  752: 'SOBYKVE12AB017E275',
#  753: 'SOBYPQZ12AB0186DE9',
#  754: 'SOBYQGA12A6D4FA864',
#  755: 'SOBYRTY12AB0181EDB',
#  756: 'SOBYRVR12A6D4FAF83',
#  757: 'SOBYSRH12A8C13AE98',
#  758: 'SOBYSSP12AAF3B32CA',
#  759: 'SOBYTGE12AB018CE3C',
#  760: 'SOBYVYT12A8C1353C5',
#  761: 'SOBYXAH12AB01884D9',
#  762: 'SOBYYIA12A67AD954A',
#  763: 'SOBYZRW12A58A7ABF1',
#  764: 'SOBZAVW12A6D4FCE4A',
#  765: 'SOBZCTQ12AB0183220',
#  766: 'SOBZCUC12A58A7D9AD',
#  767: 'SOBZCWJ12A58A7C659',
#  768: 'SOBZDFV12AB0182373',
#  769: 'SOBZETO12AB018C7FE',
#  770: 'SOBZEWE12A8C13871A',
#  771: 'SOBZFSZ12A8C13F2CA',
#  772: 'SOBZJVD12A8C13C796',
#  773: 'SOBZKGI12A8C13D0E1',
#  774: 'SOBZTDO12AB0185758',
#  775: 'SOBZVFU12A6702162C',
#  776: 'SOBZWJS12A8C141D82',
#  777: 'SOBZXCU12A67AE1818',
#  778: 'SOBZXQL12A58A78057',
#  779: 'SOBZYGP12AB0182B29',
#  780: 'SOBZZDU12A6310D8A3',
#  781: 'SOBZZER12A6D4F7FA6',
#  782: 'SOBZZMP12A8C140E31',
#  783: 'SOCAAWX12A6D4F7901',
#  784: 'SOCABGC12AF72A09AF',
#  785: 'SOCACIT12A67AE110A',
#  786: 'SOCAFDI12A8C13D10E',
#  787: 'SOCAFQG12A6701DEB5',
#  788: 'SOCAHRT12A8C13A1A4',
#  789: 'SOCAIGK12A8C143D86',
#  790: 'SOCAIKQ12A6701E578',
#  791: 'SOCAJUZ12A6701E555',
#  792: 'SOCAKHR12A58A7AE39',
#  793: 'SOCAKKQ12AB01815E7',
#  794: 'SOCALRI12A58A7BBC5',
#  795: 'SOCANXR12A8C13898D',
#  796: 'SOCAOHJ12A6D4FBC7B',
#  797: 'SOCAPQV12A67021501',
#  798: 'SOCAQPK12AB018AA3F',
#  799: 'SOCATCA12AB0181E75',
#  800: 'SOCATDE12A67AE0269',
#  801: 'SOCATVQ12A8AE46CF4',
#  802: 'SOCAZCI12A6D4F9149',
#  803: 'SOCBBGJ12AF72A0922',
#  804: 'SOCBFDJ12A67ADD163',
#  805: 'SOCBGZW12A58A7CAC2',
#  806: 'SOCBIAB12A81C219DB',
#  807: 'SOCBJEC12AB018B710',
#  808: 'SOCBJHG12AB018221C',
#  809: 'SOCBMFC12A6701D7BA',
#  810: 'SOCBNIS12AF72AB9D3',
#  811: 'SOCBNJP12AC3DFA45A',
#  812: 'SOCBNYL12A8C13404D',
#  813: 'SOCBOSF12A58A7B861',
#  814: 'SOCBQKE12AB018548E',
#  815: 'SOCBSZW12AB01891C1',
#  816: 'SOCBVSG12A8C13C219',
#  817: 'SOCBWRP12A8C1311DB',
#  818: 'SOCBXKD12A8C145834',
#  819: 'SOCCASN12B0B8069FA',
#  820: 'SOCCBPI12A8C1451B6',
#  821: 'SOCCDAW12A8C133D56',
#  822: 'SOCCEFN12A6701C548',
#  823: 'SOCCFCY12AB01867F8',
#  824: 'SOCCHGF12A8C13FFBF',
#  825: 'SOCCLHE12A81C22300',
#  826: 'SOCCOOK12A8C13EF91',
#  827: 'SOCCRVM12A6310E239',
#  828: 'SOCCSES12AB017F676',
#  829: 'SOCCWZW12AB01829DB',
#  830: 'SOCCXPY12A6D4F4773',
#  831: 'SOCCYYG12AB0184DE8',
#  832: 'SOCDGAR12AB018CE44',
#  833: 'SOCDGOY12A8C1466ED',
#  834: 'SOCDNMP12AB018440C',
#  835: 'SOCDOVE12AB01808DE',
#  836: 'SOCDQPS12A58A78C9D',
#  837: 'SOCDRSP12A58A76F5E',
#  838: 'SOCDRUZ12A8AE48614',
#  839: 'SOCDSBU12A6D4F729A',
#  840: 'SOCDVMQ12A6D4F71B0',
#  841: 'SOCDXHL12A8C137A8A',
#  842: 'SOCDXUG12B0B8064EA',
#  843: 'SOCEANL12A58A7EF4E',
#  844: 'SOCEBPI12A58A7D08E',
#  845: 'SOCECEC12A8C134FAF',
#  846: 'SOCECZH12AB017FC28',
#  847: 'SOCEGJM12A8AE481D3',
#  848: 'SOCEGXN12AB018174F',
#  849: 'SOCEIGD12A67AE0416',
#  850: 'SOCELEG12AF72A7052',
#  851: 'SOCELOG12A6D4FC1E5',
#  852: 'SOCELOZ12A58A76797',
#  853: 'SOCEMSF12A8C145464',
#  854: 'SOCENBL12A6D4F6BB0',
#  855: 'SOCEPUS12A67ADEAD5',
#  856: 'SOCESFK12AB018CF42',
#  857: 'SOCESFW12A58A7DC8C',
#  858: 'SOCEVGB12A8C140286',
#  859: 'SOCEVWT12A6D4F992A',
#  860: 'SOCEWMO12A8151CBDE',
#  861: 'SOCEWVG12A8C13DCC2',
#  862: 'SOCEYDM12A58A7C4B7',
#  863: 'SOCEZHB12A58A7AB4D',
#  864: 'SOCFBUY12AB01870A3',
#  865: 'SOCFGIT12A8C13E64F',
#  866: 'SOCFHXV12AB018DB2A',
#  867: 'SOCFIUI12A81C23E48',
#  868: 'SOCFJWH12A8C13A103',
#  869: 'SOCFMQE12AB01853A3',
#  870: 'SOCFNLP12A58A7D730',
#  871: 'SOCFPBP12AB0182D2B',
#  872: 'SOCFPSZ12A6D4FCA89',
#  873: 'SOCFQUL12A8C141CA2',
#  874: 'SOCFRBD12A6D4F752E',
#  875: 'SOCFTJO12AB018CF2D',
#  876: 'SOCFYUZ12AF729E4B6',
#  877: 'SOCGBSR12A81C2143F',
#  878: 'SOCGBXK12A6D4F780F',
#  879: 'SOCGFSH12A81C238C6',
#  880: 'SOCGHMJ12AB017D10D',
#  881: 'SOCGMIW12AB018030A',
#  882: 'SOCGMXY12A6701E069',
#  883: 'SOCGOZK12A8151BD5D',
#  884: 'SOCGVMO12A67AE24CC',
#  885: 'SOCGWCK12A67020F39',
#  886: 'SOCGXPJ12A8C142CD1',
#  887: 'SOCGXXL12B0B808865',
#  888: 'SOCGYKU12A8C13B4D9',
#  889: 'SOCGYWW12A8C13BB00',
#  890: 'SOCGYXV12AF72A0192',
#  891: 'SOCHADN12A6310ED94',
#  892: 'SOCHAXM12AB01876F8',
#  893: 'SOCHBAJ12AAF3B3A4F',
#  894: 'SOCHBAR12AB0187BA9',
#  895: 'SOCHEPE12A8C13B2A1',
#  896: 'SOCHEQE12A8C1402C1',
#  897: 'SOCHFOV12A6D4F979F',
#  898: 'SOCHJTK12A6701C153',
#  899: 'SOCHKFO12AB01860DB',
#  900: 'SOCHKWF12A58A7C9B7',
#  901: 'SOCHNDG12A8C13BA36',
#  902: 'SOCHNVD12A58A7A8A7',
#  903: 'SOCHPFL12AF72A3F64',
#  904: 'SOCHPLU12A8C13462D',
#  905: 'SOCHPTV12A6BD53113',
#  906: 'SOCHQLZ12A58A79717',
#  907: 'SOCHRXB12A8AE48069',
#  908: 'SOCHSJD12A6D4F926E',
#  909: 'SOCHSYC12AB017B5B9',
#  910: 'SOCHTHF12AB017E206',
#  911: 'SOCHTHV12A6D4F9791',
#  912: 'SOCHWPT12AB0184F15',
#  913: 'SOCHXEH12A8C1425D2',
#  914: 'SOCHXTG12A58A779A0',
#  915: 'SOCHYDE12A8C13E438',
#  916: 'SOCHYVZ12A6D4F5908',
#  917: 'SOCIAFQ12AF72A154F',
#  918: 'SOCIGMX12A8C144150',
#  919: 'SOCIHMS12A8C142CC7',
#  920: 'SOCINEQ12AB0189F08',
#  921: 'SOCINRJ12A8C132D3F',
#  922: 'SOCIUSI12AB018DD03',
#  923: 'SOCJACI12B350584E6',
#  924: 'SOCJAMC12A8C13F245',
#  925: 'SOCJBOJ12A8C142D05',
#  926: 'SOCJCVE12A8C13CDDB',
#  927: 'SOCJCVW12A8AE47537',
#  928: 'SOCJHPS12A6D4F8523',
#  929: 'SOCJHXN12AB0188C8B',
#  930: 'SOCJNRV12A6D4F70B5',
#  931: 'SOCJPWM12AF72A781A',
#  932: 'SOCJQCK12A6D4F7F99',
#  933: 'SOCJQTG12AC9097645',
#  934: 'SOCJSPF12A8C1376EF',
#  935: 'SOCJTXC12A6701E7EA',
#  936: 'SOCJVDJ12A8C1375E3',
#  937: 'SOCJWZY12A67021D18',
#  938: 'SOCJXRD12AB0189B2D',
#  939: 'SOCJZHU12A67ADE987',
#  940: 'SOCKAEI12A8C1422C8',
#  941: 'SOCKCYN12A6D4FB112',
#  942: 'SOCKFLZ12A81C222D4',
#  943: 'SOCKFVF12A8C1442A7',
#  944: 'SOCKHZK12AB018894F',
#  945: 'SOCKIDE12A6D4F6542',
#  946: 'SOCKJVP12A6D4F920C',
#  947: 'SOCKJWI12AB018006A',
#  948: 'SOCKLYO12AF72A877F',
#  949: 'SOCKPDE12A8C142F18',
#  950: 'SOCKPSR12A8C136FC8',
#  951: 'SOCKRRL12A8C13C4AB',
#  952: 'SOCKSGZ12A58A7CA4B',
#  953: 'SOCKUUJ12A6D4FA41C',
#  954: 'SOCKUWT12AB01876D7',
#  955: 'SOCKWAJ12A8C144B65',
#  956: 'SOCKWJW12AC468A1E5',
#  957: 'SOCKYBP12A8AE48678',
#  958: 'SOCKYCG12A58A78E37',
#  959: 'SOCKZGC1280EC90D76',
#  960: 'SOCKZIS12A8AE47FE0',
#  961: 'SOCLANN12AC907598C',
#  962: 'SOCLCYG12A6D4FDC71',
#  963: 'SOCLFCD12A6D4FA66D',
#  964: 'SOCLHSF12A8C13D1F8',
#  965: 'SOCLMAD12AB017FC09',
#  966: 'SOCLNOB12A8AE48670',
#  967: 'SOCLQES12A58A7BB1D',
#  968: 'SOCLQGL12A58A7A50A',
#  969: 'SOCLRFZ12A6D4F5975',
#  970: 'SOCLSLO12A8C137815',
#  971: 'SOCLUOZ12A8C138A05',
#  972: 'SOCLVXH12AC468DC14',
#  973: 'SOCMDYI12A6D4F78A3',
#  974: 'SOCMEJM12AF72A48D0',
#  975: 'SOCMESJ12A6D4F839A',
#  976: 'SOCMFXH12A6D4F8420',
#  977: 'SOCMGYC12A8C134ED4',
#  978: 'SOCMHES12AB0186FCF',
#  979: 'SOCMHFG12AB017FFA7',
#  980: 'SOCMHGT12A8C138D8A',
#  981: 'SOCMHYC12A8AE47EFC',
#  982: 'SOCMIPA12A6310E961',
#  983: 'SOCMKES12A58A7AC2B',
#  984: 'SOCMNRG12AB0189D3F',
#  985: 'SOCMRWF12AB018AC92',
#  986: 'SOCMSRR12A81C22F45',
#  987: 'SOCMWUM12AF72A56B1',
#  988: 'SOCMZOW12AB017B857',
#  989: 'SOCNAPQ12AAA15EE26',
#  990: 'SOCNAXF12A6D4F9B34',
#  991: 'SOCNAXX12AAF3B3823',
#  992: 'SOCNCFO12A8C13971C',
#  993: 'SOCNCGL127D9786D66',
#  994: 'SOCNIFM12A8C13D73B',
#  995: 'SOCNKUW12A8C13DE89',
#  996: 'SOCNLEI12A67021565',
#  997: 'SOCNOXN12A6D4F4CBB',
#  998: 'SOCNPTC12A8C144911',
#  999: 'SOCNVQU12A58A7DB65',
#  ...}

# %%
# Get recommendations for user 0 
top_recommendations = generate_recommendations(0, user_predictions, sparse_matrix, song_id_map, n=10)
top_recommendations
# Out:
# ['SORPBQE12AF729D727',
#  'SONBYCV12A58A7CCD7',
#  'SOABNPW12A6D4FC9B5',
#  'SOCAIGK12A8C143D86',
#  'SODCAJF12AB018371E',
#  'SOBHHHO12A58A78B94',
#  'SOXQALX12AB0181468',
#  'SORXWPW12A81C224BE',
#  'SOHVJKX12A670208ED',
#  'SOZZLTY12A67AE0AD0']

# %%
# Get song titles from songs_df
song_df[song_df['song_id'].isin(top_recommendations)]
# Out:
#         Unnamed: 0             song_id                       title  \
# 207667      207714  SORPBQE12AF729D727           Old Yellow Bricks
# 246797      246866  SOXQALX12AB0181468           Other Mathematics
# 251364      251435  SONBYCV12A58A7CCD7  One Last Kiss (LP Version)
# 369652      369788  SOCAIGK12A8C143D86                Furious Rose
# 430486      430671  SOABNPW12A6D4FC9B5      The Canals Of Our City
# 539856      540161  SOHVJKX12A670208ED         For What It's Worth
# 579224      579563  SODCAJF12AB018371E          Once In A Lifetime
# 935065      935909  SOZZLTY12A67AE0AD0                       Ruska
# 937945      938796  SOBHHHO12A58A78B94                      Jeremy
# 944771      945630  SORXWPW12A81C224BE                All Fired Up
#
#                               release     artist_name  year  \
# 207667      Favourite Worst Nightmare  Arctic Monkeys  2007
# 246797              Other Mathematics       Ex-Models     0
# 251364  From Them_ Through Us_ To You     Madina Lake     0
# 369652                    Firecracker       Lisa Loeb  1997
# 430486             The Gulag Orkestar          Beirut  2005
# 539856                        Best Of   The Cardigans  2003
# 579224                Sonic Firestorm     Dragonforce  2004
# 935065                   Apocalyptica    Apocalyptica  2005
# 937945                            Ten       Pearl Jam  1991
# 944771             Our Love To Admire        Interpol     0
#
#                                     title_artist
# 207667        Old Yellow Bricks - Arctic Monkeys
# 246797             Other Mathematics - Ex-Models
# 251364  One Last Kiss (LP Version) - Madina Lake
# 369652                  Furious Rose - Lisa Loeb
# 430486           The Canals Of Our City - Beirut
# 539856       For What It's Worth - The Cardigans
# 579224          Once In A Lifetime - Dragonforce
# 935065                      Ruska - Apocalyptica
# 937945                        Jeremy - Pearl Jam
# 944771                   All Fired Up - Interpol

# %%
# Above shows, according to our data and SVD model, for user 0 their top 10 recommended songs that they have supposedly not listen to

# %%
# -- Evaluation of Model - RMSE --

# %%
# We will evaluate on user 0

# %%
# To evaluate this model we need to compare for this user, their original listen counts with the model's preictions

# %%
# Creating mapping from codes to user_id, from the csr matrix user to their actual user_id in the original df 
user_id_mapping = {code: user_id for code, user_id in enumerate(triplets_df['user_id'].cat.categories)}

# %%
original_user_id = user_id_mapping[0]
original_user_id
# Out:
# '00003a4459f33b92906be11abe0e93efc423c0ff'

# %%
# Identify this user's listen_counts

# %%
user_data = triplets_df[triplets_df['user_id'] == '00003a4459f33b92906be11abe0e93efc423c0ff']
true_listens = user_data.set_index('song_id')['listen_count']
true_listens = true_listens.sort_index()
true_listens
# Out:
# song_id
# SOJJRVI12A6D4FBE49    1
# SOKJWZB12A6D4F9487    4
# SOMZHIH12A8AE45D00    3
# SONFEUF12AAF3B47E3    3
# SOVMGXI12AF72A80B0    1
# SOVNPBK12A6D4F6A67    2
# SOWVBDQ12A8C13503D    3
# Name: listen_count, dtype: int64

# %%
# Predicted listens from SVD for all songs
predicted_listens = predict_for_user(0, U, sigma, Vt)
predicted_listens_series = pd.Series(predicted_listens, index=song_id_map.values())
predicted_listens_series
# Out:
# SOAAAGQ12A8C1420C8    0.001916
# SOAACPJ12A81C21360    0.012101
# SOAACSG12AB018DC80    0.000532
# SOAAEJI12AB0188AB5    0.002232
# SOAAFAC12A67ADF7EB   -0.021715
#                         ...
# SOZZTNF12A8C139916   -0.004585
# SOZZVWB12AB0189C30   -0.016654
# SOZZWZV12A67AE140F   -0.009501
# SOZZYAO12A6701FF36    0.007261
# SOZZZPV12A8C1444B5   -0.004868
# Length: 10000, dtype: float32

# %%
# Listen counts predicted by model for listened songs 
user_pred = predicted_listens_series[true_listens.index]
user_pred
# Out:
# song_id
# SOJJRVI12A6D4FBE49    0.966738
# SOKJWZB12A6D4F9487    2.079542
# SOMZHIH12A8AE45D00    2.437272
# SONFEUF12AAF3B47E3    1.940426
# SOVMGXI12AF72A80B0    0.969132
# SOVNPBK12A6D4F6A67    1.921473
# SOWVBDQ12A8C13503D    3.072544
# dtype: float32

# %%
# On first glance a lot of these numbers are quite promising with the first one, and bottom three being practically spot on
# The others are only 1-1.5 off

# %%
# Calculate RMSE
mae = mean_absolute_error(true_listens, user_pred)
rmse = np.sqrt(mean_squared_error(true_listens, user_pred))
rmse
# Out:
# 0.8569885408570102

# %%
triplets_df['listen_count'].describe()
# Out:
# count    1.973852e+06
# mean     2.542916e+00
# std      3.037282e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      3.000000e+00
# max      2.200000e+01
# Name: listen_count, dtype: float64

# %% [markdown]
# ## Evaluation
#
# Interpreting this RMSE is not entirely straightforward. Given that we are predicting a listen count, being less than 1 off is not too bad. There are quite a few data points where listen counts are in the 10s, with the highest being 22; in such cases, being 0.85 off is good.
#
# Moreover, the standard deviation is 3, meaning that listen counts vary around the mean quite a lot. Therefore, for the RMSE to be considerably less is a promising sign. In other words, it reduces the data's error to a level significantly lower than the typical variation.
#
# Additionally, in a recommender system, predicting a listen count within 1 count of accuracy is probably not necessary for recommending a song. The recommendation doesn't need to know exactly how many listens there will be, just whether the user will like the song—i.e., if the listen count is above a certain threshold. For example, if the model predicts 5 listens when the actual count is 10, it is still effective in identifying that the user likes or listens to the song.
#
# However, it's important to note that this RMSE can change with different users. For users with more songs listened to and listen counts closer to the average, the user's RMSE can be as low as 0.6 (as in the case of user 4). This makes sense because, generally speaking, having more data to predict from tends to lead to higher accuracy. It's also common for models to struggle to predict more extreme values, as they are mostly trained on average values.

# %%
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
# The next stages will be to try and improve the model as well as get RMSE values for the whole matrix, not just on a user by user basis
# One way to do this is with a truncated svd

# Secondly, given we have RMSE that is low and that may continue to decrease with higher values of K, it's important to check if this is not just the model overfitting to the training data.
# If our model is trained on the whole matrix and performs well, it may not necessarily perform well on unseen data.
# So we will also use cross validation to analyse how well the model learns on unseen data as well as a holdout set that we can test against at the end

# -- Summary of Next stages -- 
# 1. Define holdout set
# 2. Get RMSE values over the whole matrix with Truncated SVD
# 3. Carry out cross validation
# 4. Test model against holdout set
# 5. Evaluation

# %%
# 1. Define holdout set
train_val_data, holdout_data = train_test_split(sparse_matrix, test_size=0.1, random_state=42)

# %%
# 2. Training and RMSE calculation on whole matrix (truncated SVD)
# NOTE: k = 1500 is the highest k value that computational resources allowed for in this case
k = 1500
svd = TruncatedSVD(n_components=k)
U = svd.fit_transform(train_val_data)
Vt = svd.components_
predicted_ratings = np.dot(U, Vt)

# %%
# For the RMSE calculation its essential that the index for the prediction and the train_val align properly
# We can test this with the steps below
non_zero_indices = train_val_data.nonzero()
actual_ratings = train_val_data.data
predicted_ratings = np.dot(U, Vt)
predicted_ratings_at_indices = predicted_ratings[non_zero_indices]

# %%
# Check the shapes are the same 
print(f"Actual Ratings Shape: {actual_ratings.shape}")
print(f"Predicted Ratings Shape: {predicted_ratings_at_indices.shape}")
# Out:
# Actual Ratings Shape: (1779590,)
# Predicted Ratings Shape: (1779590,)

# %%
# Print the first few pairs, given the predictions are all close to the actual would suggest the indicies are aligned
for i in range(3):
    print(f"Actual: {actual_ratings[i]}, Predicted: {predicted_ratings_at_indices[i]}")
# Out:
# Actual: 1.0, Predicted: 1.0016509294509888
# Actual: 2.0, Predicted: 1.8935208320617676
# Actual: 3.0, Predicted: 2.9559836387634277

# %%
# print rmse
rmse = np.sqrt(mean_squared_error(train_val_data.data, predicted_ratings[train_val_data.nonzero()]))

# %%
rmse
# Out:
# 2.015817

# %%
# 3. Cross validation

kf = KFold(n_splits=5) 
k = 1500 
results = []

for train_index, test_index in kf.split(train_val_data):
    train_data = train_val_data[train_index]
    test_data = train_val_data[test_index]

    # Run trucated SVD and get predictions and rmse as before but for each fold
    svd = TruncatedSVD(n_components=k)  
    U = svd.fit_transform(train_data)
    Vt = svd.components_
    predicted_ratings = np.dot(U, Vt)
    non_zero_indices = test_data.nonzero()
    actual_ratings = test_data.data
    predicted_ratings_at_indices = predicted_ratings[non_zero_indices]
    rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings_at_indices))
    results.append(rmse)

# %%
average_rmse = np.mean(results)
average_rmse
# Out:
# 3.9633873

# %%
# 4. Test the model against the holdout set 
# As we are keeping k the same, we can now use the svd already trained, against the holdout set, to again see how the model performs on unseen data
# Out:
# TruncatedSVD(n_components=1500)

# %%
holdout_dense = holdout_data.toarray()
U_holdout = svd.transform(holdout_dense)

# %%
predicted_ratings_holdout = np.dot(U_holdout, Vt)

# %%
non_zero_indices = holdout_data.nonzero()
actual_ratings_holdout = holdout_data.data
predicted_ratings_at_indices_holdout = predicted_ratings_holdout[non_zero_indices]

# %%
holdout_rmse = np.sqrt(mean_squared_error(actual_ratings_holdout, predicted_ratings_at_indices_holdout))
print(f"Holdout RMSE: {holdout_rmse}")
# Out:
# Holdout RMSE: 2.344604253768921

# %% [markdown]
# # --- Final Evaluation ---
#
# We can see from comparing the RMSE on the training/validation data and the holdout set that the model still performs well on unseen data. This indicates that the model generalizes well and exhibits minimal overfitting, as the RMSE is only slightly higher (+0.3) for the unseen data set. An RMSE of 2.02 and 2.34 is quite good for this dataset, but this was achieved with a value of k only at 1500, as any higher value led to memory constraints.
#
# Having already tested with a k value as high as 6000 earlier (not truncated), we know that the model's performance improved significantly with this increase. This makes sense because, with 2 million unique user-song pairs over 10,000 different songs, a higher k allows for capturing more latent features and patterns in the data. It's almost certain that the RMSE would have come down significantly for both the training data and the holdout test. The question is how much less the RMSE on the holdout set would decrease compared to the training set, or how much the higher k value would cause overfitting.
#
# It's likely that the model would begin to overfit more at higher k values, so while the RMSE on the holdout set would decrease, it would probably not decrease as much as it would on the training/validation data. This is because, as k gets too large, it starts to fit the noise in the data.
#
# Overall, it's unfortunate that computational constraints didn't allow for testing on higher k values, as it is highly likely both RMSEs would be lower. Additionally, this would have allowed for more extensive hyperparameter tuning to further optimize the model.
#
# #### Addressing the 3.96 RMSE Cross-Validation Result
# The cross-validation RMSE of 3.96 is quite high, suggesting that when the folds in the training/validation data are unseen, the model generally does not perform well. This 3.96 RMSE indicates more variation than the overall standard deviation. Cross-validation provides a rigorous evaluation of model performance by testing it on various unseen subsets of the data. The higher RMSE of 3.96 suggests that the model's performance is less consistent across different subsets.
#
# #### There are several reasons why this might have occurred:
#
# - Data Split: Depending on how the data is split, certain folds might contain users or items that are more challenging to predict, leading to a higher RMSE in those specific folds.
# - Training Data Size: With smaller-sized folds, the model may need larger amounts of data to train effectively.
# - Overfitting: If the original model (k = 1500) is slightly overfitting to the training/validation data, it might perform better on that data than on the more varied data in cross-validation.
# - Noise Amplification: Cross-validation could amplify the effects of excessive noise in the dataset.
#
# #### Improving the Cross-Validation RMSE Score
#
# - Investigate whether specific folds are contributing disproportionately to the high RMSE.
# - Examine the RMSE per fold to identify any outliers.
# - Explore alternative methods for regularization, feature selection, or data preprocessing.
# - Find workarounds for computational constraints and then cross-validate with higher k values.
